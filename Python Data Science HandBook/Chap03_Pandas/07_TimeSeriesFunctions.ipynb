# %%
# Native Python functions

from datetime import datetime
datetime(year=2015, month=7, day=4)
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
from dateutil import parser
date = parser.parse("4th of july, 2015")
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
import numpy as np

# Weaknesses in native python introduced some improvements in numpy
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
# After formatting the date to datetime format we can do vector operations
date + np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
# Day based datetime
np.datetime64('2015-07-04')
# Out:
# numpy.datetime64('2015-07-04')

# %%
# Minute based datetime
np.datetime64('2015-07-04 12:00')
# Out:
# numpy.datetime64('2015-07-04T12:00')

# %%
# Nanosecond based datetime
np.datetime64('2015-07-04 12:59:59.50', 'ns')
# Out:
# numpy.datetime64('2015-07-04T12:59:59.500000000')

# %%
# Numpy lacks several convenient methods and functions which are addressed in Pandas
# Uses efficient storage and vectorized interface
# Date and Time in Pandas
import pandas as pd

date = pd.to_datetime('4th of july, 2015')
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#                '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#               dtype='datetime64[ns]', freq=None)

# %%
# Indexing by time
index = pd.DatetimeIndex(['2014-07-04', '2014-08-04', '2015-07-04', '2015-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
data['2014-07-04':'2015-07-04']
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# dtype: int64

# %%
data['2015']
# Out:
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015, 7, 3), '4th of July, 2015', '2015-Jul-6', '07-07-2015', '20150708'])
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#              '2015-07-08'],
#             dtype='period[D]', freq='D')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
pd.date_range('2015-07-03', '2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.period_range('2015-07', periods=8, freq='M')
# Out:
# PeriodIndex(['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#              '2016-01', '2016-02'],
#             dtype='period[M]', freq='M')

# %%
pd.timedelta_range(0, periods=10, freq='H')
# Out:
# TimedeltaIndex(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#                 '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %%
pd.timedelta_range(0, periods=9, freq="2H30T")
# Out:
# TimedeltaIndex(['00:00:00', '02:30:00', '05:00:00', '07:30:00', '10:00:00',
#                 '12:30:00', '15:00:00', '17:30:00', '20:00:00'],
#                dtype='timedelta64[ns]', freq='150T')

# %%
# Set business day offset
from pandas.tseries.offsets import BDay
pd.date_range('2015-07-01', periods=5, freq=BDay())
# Out:
# DatetimeIndex(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-06',
#                '2015-07-07'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas_datareader import data
goog = data.DataReader('GOOG', start='2004', end='2016', data_source='google')
goog.head()
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-26-74e03969485d> in <module>()
#       1 from pandas_datareader import data
# ----> 2 goog = data.DataReader('GOOG', start='2004', end='2016', data_source='google')
#       3 goog.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     314                                  chunksize=25,
#     315                                  retry_count=retry_count, pause=pause,
# --> 316                                  session=session).read()
#     317
#     318     elif data_source == "iex":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py in __init__(self, symbols, start, end, retry_count, pause, session, chunksize)
# ...

# %%
#Example of Seattle Bicycle count
data = pd.read_csv('..\Data\FremontBridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge East Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
data.columns = ['West', 'East']
data['Total'] = data.eval('West + East')
data.dropna().describe()
# Out:
#                West          East         Total
# count  54735.000000  54735.000000  54735.000000
# mean      52.619530     58.300850    110.920380
# std       68.034365     84.733147    140.018123
# min        0.000000      0.000000      0.000000
# 25%        7.000000      7.000000     15.000000
# 50%       29.000000     29.000000     60.000000
# 75%       70.000000     70.000000    144.000000
# max      698.000000    717.000000    957.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

data.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
#Weekly bicycle crossings of Seattle’s Fremont bridge

weekly = data.resample('W').sum() # Resample by week
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');

# %%
# Weekly bicycle crossings of Seattle’s Fremont bridge

daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count');

# %%
daily.rolling(50, center=True,
win_type='gaussian').sum(std=10).plot(style=[':', '--', '-']);

# %%
# Average daily bicycle counts

by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);

# %%
weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()

import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.ix['Weekday'].plot(ax=ax[0], title='Weekdays',
xticks=hourly_ticks, style=[':', '--', '-'])
by_time.ix['Weekend'].plot(ax=ax[1], title='Weekends',
xticks=hourly_ticks, style=[':', '--', '-']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-3e6aa1e88a38> in <module>()
#       5 fig, ax = plt.subplots(1, 2, figsize=(14, 5))
#       6 by_time.ix['Weekday'].plot(ax=ax[0], title='Weekdays',
# ----> 7 xticks=hourly_ticks, style=[':', '--', '-'])
#       8 by_time.ix['Weekend'].plot(ax=ax[1], title='Weekends',
#       9 xticks=hourly_ticks, style=[':', '--', '-']);
#
# NameError: name 'hourly_ticks' is not defined
