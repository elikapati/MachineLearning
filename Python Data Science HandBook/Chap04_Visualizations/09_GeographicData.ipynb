# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
m.bluemarble(scale=0.5);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-961a8551716d> in <module>()
#       1 plt.figure(figsize=(8, 8))
#       2 m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)
# ----> 3 m.bluemarble(scale=0.5);
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in bluemarble(self, ax, scale, **kwargs)
#    3971             return self.warpimage(image='bluemarble',ax=ax,scale=scale,**kwargs)
#    3972         else:
# -> 3973             return self.warpimage(image='bluemarble',scale=scale,**kwargs)
#    3974
#    3975     def shadedrelief(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4178                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4179             # plot warped rgba image.
# -> 4180             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4181             # for hammer projection, use clip path defined by
#    4182             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None,
                width=8E6, height=8E6,
                lat_0=45, lon_0=-100,)
m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting
x, y = m(-122.3, 47.6)
plt.plot(x, y, 'ok', markersize=5)
plt.text(x, y, ' Seattle', fontsize=12)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-283b094e0483> in <module>()
#       3                 width=8E6, height=8E6,
#       4                 lat_0=45, lon_0=-100,)
# ----> 5 m.etopo(scale=0.5, alpha=0.5)
#       6
#       7 # Map (long, lat) to (x, y) for plotting
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in etopo(self, ax, scale, **kwargs)
#    4006             return self.warpimage(image='etopo',ax=ax,scale=scale,**kwargs)
#    4007         else:
# -> 4008             return self.warpimage(image='etopo',scale=scale,**kwargs)
#    4009
#    4010     def warpimage(self,image="bluemarble",scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4178                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4179             # plot warped rgba image.
# -> 4180             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4181             # for hammer projection, use clip path defined by
#    4182             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
from itertools import chain

def draw_map(m, scale=0.2):
# draw a shaded-relief image
    m.shadedrelief(scale=scale)
    
    # lats and longs are returned as a dictionary
    lats = m.drawparallels(np.linspace(-90, 90, 13))
    lons = m.drawmeridians(np.linspace(-180, 180, 13))

    # keys contain the plt.Line2D instances
    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)

    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='w')

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='cyl', resolution=None,
                llcrnrlat=-90, urcrnrlat=90,
                llcrnrlon=-180, urcrnrlon=180, )
draw_map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-6179cc0c0104> in <module>()
#       3                 llcrnrlat=-90, urcrnrlat=90,
#       4                 llcrnrlon=-180, urcrnrlon=180, )
# ----> 5 draw_map(m)
#
# <ipython-input-20-053153c8a0fb> in draw_map(m, scale)
#       3 def draw_map(m, scale=0.2):
#       4 # draw a shaded-relief image
# ----> 5     m.shadedrelief(scale=scale)
#       6
#       7     # lats and longs are returned as a dictionary
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3988             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3989         else:
# -> 3990             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3991
#    3992     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4188         else:
#    4189             # bmproj True, no interpolation necessary.
# -> 4190             im = self.imshow(self._bm_rgba,ax=ax,**kwargs)
#    4191         # clip to map limbs
#    4192         im,c = self._cliplimb(ax,im)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
fig = plt.figure(figsize=(8, 6), edgecolor='w')
m = Basemap(projection='moll', resolution=None,
lat_0=0, lon_0=0)
draw_map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-d15934420ccd> in <module>()
#       2 m = Basemap(projection='moll', resolution=None,
#       3 lat_0=0, lon_0=0)
# ----> 4 draw_map(m)
#
# <ipython-input-20-053153c8a0fb> in draw_map(m, scale)
#       3 def draw_map(m, scale=0.2):
#       4 # draw a shaded-relief image
# ----> 5     m.shadedrelief(scale=scale)
#       6
#       7     # lats and longs are returned as a dictionary
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3988             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3989         else:
# -> 3990             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3991
#    3992     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4178                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4179             # plot warped rgba image.
# -> 4180             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4181             # for hammer projection, use clip path defined by
#    4182             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='ortho', resolution=None,
lat_0=50, lon_0=0)
draw_map(m);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6d272b4410b2> in <module>()
#       2 m = Basemap(projection='ortho', resolution=None,
#       3 lat_0=50, lon_0=0)
# ----> 4 draw_map(m);
#
# <ipython-input-20-053153c8a0fb> in draw_map(m, scale)
#       3 def draw_map(m, scale=0.2):
#       4 # draw a shaded-relief image
# ----> 5     m.shadedrelief(scale=scale)
#       6
#       7     # lats and longs are returned as a dictionary
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3988             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3989         else:
# -> 3990             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3991
#    3992     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4178                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4179             # plot warped rgba image.
# -> 4180             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4181             # for hammer projection, use clip path defined by
#    4182             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution=None,
lon_0=0, lat_0=50, lat_1=45, lat_2=55,
            width=1.6E7, height=1.2E7)
draw_map(m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-b66f53551fc3> in <module>()
#       3 lon_0=0, lat_0=50, lat_1=45, lat_2=55,
#       4             width=1.6E7, height=1.2E7)
# ----> 5 draw_map(m)
#
# <ipython-input-20-053153c8a0fb> in draw_map(m, scale)
#       3 def draw_map(m, scale=0.2):
#       4 # draw a shaded-relief image
# ----> 5     m.shadedrelief(scale=scale)
#       6
#       7     # lats and longs are returned as a dictionary
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in shadedrelief(self, ax, scale, **kwargs)
#    3988             return self.warpimage(image='shadedrelief',ax=ax,scale=scale,**kwargs)
#    3989         else:
# -> 3990             return self.warpimage(image='shadedrelief',scale=scale,**kwargs)
#    3991
#    3992     def etopo(self,ax=None,scale=None,**kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in warpimage(self, image, scale, **kwargs)
#    4178                     self._bm_rgba_warped = self._bm_rgba_warped.filled(0.)
#    4179             # plot warped rgba image.
# -> 4180             im = self.imshow(self._bm_rgba_warped,ax=ax,**kwargs)
#    4181             # for hammer projection, use clip path defined by
#    4182             # projection limb (patch created in drawmapboundary).
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in imshow(self, *args, **kwargs)
#    3322             ret =  ax.imshow(*args, **kwargs)
#    3323         finally:
# -> 3324             self._restore_hold(ax)
#    3325         # reset current active image (only if pyplot is imported).
#    3326         if plt:
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute
