# %%
from mpl_toolkits.basemap import Basemap
#import numpy as np
import matplotlib.pyplot as plt

m = Basemap(projection='mill',
           llcrnrlat = 25,
           llcrnrlon = -130,
           urcrnrlat = 50,
           urcrnrlon = -60, 
           resolution='l')

m.drawcoastlines()
m.drawcountries()
m.drawstates()
#m.drawcounties()
#m.etopo()
#m.bluemarble()

xs = []
ys = []
NYClat, NYClon = 40.7127, -74.0059
xpt, ypt = m(NYClon, NYClat)
xs.append(xpt)
ys.append(ypt)
m.plot(xpt, ypt, 'c*', markersize=25)

LAlat, LAlon = 34.05, -118.25
xpt, ypt = m(LAlon, LAlat)
xs.append(xpt)
ys.append(ypt)
m.plot(xpt, ypt, 'r^', markersize=25)


m.plot(xs, ys)

# draw the title.
plt.title('Azimuthal Equidistant Projection')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-a5f7f674fe00> in <module>()
#      23 xs.append(xpt)
#      24 ys.append(ypt)
# ---> 25 m.plot(xpt, ypt, 'c*', markersize=25)
#      26
#      27 LAlat, LAlon = 34.05, -118.25
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in with_transform(self, x, y, *args, **kwargs)
#     565             # convert lat/lon coords to map projection coords.
#     566             x, y = self(x,y)
# --> 567         return plotfunc(self,x,y,*args,**kwargs)
#     568     return with_transform
#     569
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in plot(self, *args, **kwargs)
#    3292             ret =  ax.plot(*args, **kwargs)
#    3293         finally:
# -> 3294             self._restore_hold(ax)
#    3295         # set axes limits to fit map region.
#    3296         self.set_axes_limits(ax=ax)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in _restore_hold(self, ax)
#    3236     def _restore_hold(self, ax):
#    3237         if hasattr(ax, '_hold'):
# -> 3238             ax._hold = self._tmp_hold
#    3239
#    3240     @_transform1d
#
# AttributeError: can't set attribute
